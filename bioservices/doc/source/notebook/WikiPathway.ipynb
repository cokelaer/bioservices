# %% [markdown]
# # WikiPathway service from BioServices

# %%
from bioservices import *
# %pylab inline
# let us define the dpi 
matplotlib.rcParams['savefig.dpi'] = 400
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['copy']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
s = Wikipathway()
# Note that by default, organism is human:
s.organism
# Out:
# INFO:root:Initialising Wikipathway service (WSDL)
# INFO:root:Fetching organisms...
# 'Homo sapiens'

# %% [markdown]
# Let us find the pathways that contains MTOR and let us play with the first one [0].

# %%
s.findPathwaysByText("MTOR")[0]
# Out:
# <SOAPpy.Types.structType result at 85607560>: {'name': '', 'url': 'http://www.wikipathways.org/index.php/Pathway:WP2320', 'id': 'WP2320', 'score': '1.4225621', 'species': '', 'revision': '0'}

# %%
res = s.getColoredPathway("WP2320")

# %%
from IPython.display import SVG

# %%
SVG(res)

# %% [markdown]
# Let us find all interactions related to MTOR and plot the interaction graph

# %%
interactions = s.findInteractions("MTOR")

# %%
print interactions
# Out:
# [('mTOR\ninhibitors', 'mTOR'), ('AKT1', 'MTOR'), ('EEF2', 'MTOR'), (['', 'TSC2', 'TSC1'], 'mTOR'), ('PI3K (III)', 'mTOR'), ('AKT3', 'mTOR'), ('AKT1', 'MTOR'), ('AKT1', 'MTOR'), ('AKT1', 'MTOR'), ('AKT1', 'MTOR'), ('', 'MTOR'), ('TSC2', 'MTOR'), ('AKT1', 'MTOR'), ('AKT1', 'MTOR'), ('AKT1', 'MTOR'), ('AKT1', 'MTOR'), ('FKBP1A', 'MTOR'), ('FKBP1B', 'MTOR'), ('AKT1', 'MTOR'), ('TSC2', 'MTOR'), ('TNF alpha', 'mTOR'), ('RHEB', 'MTOR'), ('Akt', 'MTOR'), ('AKT2', 'MTOR'), ('Rheb', 'mTOR'), (['', 'AKT2', 'AKT1'], 'mTOR'), (['AKT2', '', 'AKT1'], 'mTOR'), ('MTOR', 'RPS6KB1'), ('MTOR', 'EIF4EBP1'), ('MTOR', 'RPS6KB1'), ('MTOR', 'TSC2'), ('mTOR', 'P70S6K'), ('mTOR', 'eIF-4EBP'), ('mTOR', 'AKT3'), ('MTOR', 'RPS6'), ('MTOR', 'EIF4EBP1'), ('MTOR', 'RPS6KB1'), ('MTOR', 'EIF4EBP1'), ('MTOR', 'EIF4E'), ('MTOR', 'RPS6KB1'), ('MTOR', 'AKT dependent'), ('MTOR', 'RPS6KB1'), ('MTOR', 'EIF4EBP1'), ('MTOR', ['SREBF1', '', 'SREBF2']), ('MTOR', 'RPS6KA1'), ('MTOR', 'EIF4EBP1'), ('MTOR', 'RPS6KB1'), ('MTOR', 'EIF4EBP1'), ('MTOR', 'RPS6KB1'), ('MTOR', 'PDPK1'), ('MTOR', 'Angiogenesis'), ('MTOR', 'EIF4EBP1'), ('MTOR', 'p70S6K'), ('mTOR', 'Protein\nSynthesis'), ('mTOR', 'Protein Synthesis'), ('mTOR', 'Protein Synthesis'), ('mTOR', 'Hypertrophic gene transcription'), (['Akt1', 'Akt2', ''], ['', 'mTOR', 'Raptor']), (['', 'mTOR', 'Raptor'], '4E-BP1'), (['', 'mTOR', 'Raptor'], ['p70S6Ka', 'p70S6Kb', '']), ('MTOR_HUMAN', 'RICTOR'), (['FKBP1A', '', 'Rapamycin'], ['MLST8', '', 'RPTOR', 'MTOR']), ('PRKAB1', ['MLST8', '', 'RPTOR', 'MTOR']), (['MLST8', '', 'RPTOR', 'MTOR'], 'Ribosome biogenesis'), (['MLST8', '', 'RPTOR', 'MTOR'], 'RPS6KB1'), (['MLST8', '', 'RPTOR', 'MTOR'], 'ULK1'), (['', 'MTOR', 'RICTOR', 'MAPKAP1', 'MLST8'], 'PRKCA'), (['', 'MTOR', 'RICTOR', 'MAPKAP1', 'MLST8'], 'AKT1'), (['', 'MTOR', 'RICTOR', 'MAPKAP1', 'MLST8'], 'RAC1'), ('PKB/Akt', 'cell proliferation and progression\nMTOR signaling etc.')]

# %%
from cellnopt.core import *
c = CNOGraph()
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
for interaction in interactions:
    inputs, outputs = interaction
    if isinstance(inputs, str):
        inputs = [inputs]
    if isinstance(outputs, str):
        outputs = [outputs]
        
    for n1 in inputs:
        for n2 in outputs:
            if n1 and n2 and n1!=n2:
                c.add_edge(n1, n2, link="+")

# %%
c.graph_options['graph']['dpi'] = 200
c.plot()
# Out:
# INFO:root:dot -Tpng /tmp/tmpz2GMhx.dot -o /tmp/tmp5HYNUd.png
